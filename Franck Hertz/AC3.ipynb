# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
file_path1 =  "C:/Programación/Lab Intermedio/Franck Hertz/Datos 231.xlsx" 
file_path2 =  "C:/Programación/Lab Intermedio/Franck Hertz/Datos 232.xlsx" 
file_path3 =  "C:/Programación/Lab Intermedio/Franck Hertz/Datos 233.xlsx"
# Leer los archivos Excel
data1 = pd.read_excel(file_path1)
data2 = pd.read_excel(file_path2)
data3 = pd.read_excel(file_path3)
voltage1, current1 = data1['Voltage U1'], data1['Corriente IA']
voltage2, current2 = data2['Voltage U1'], data2['Corriente IA']
voltage3, current3 = data3['Voltage U1'], data3['Corriente IA']

# Gráfico de Voltaje vs Corriente para ambos conjuntos de datos en el mismo plot
plt.figure(figsize=(10, 6))

# Graficar el primer conjunto

# Graficar el segundo conjunto
plt.plot(voltage1, current1, label="$U_{2}=2$", color="b")
plt.plot(voltage2, current2, label="$U_{2}=1.5$", color="g")


plt.plot(voltage3, current3, label="$U_{2}=1$", color="y")
# Configuración de la gráfica
plt.title("Voltaje vs Corriente para distintos valores de $U_{2}$")
plt.xlabel("Voltaje (V)")
plt.ylabel("Corriente (nA)")
plt.legend()




plt.show()

# Conjunto de Datos 1
