# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy.optimize import curve_fit

data = "C:/Programación/Lab Intermedio/Torque Magnético/AC2.xlsx"
data = pd.read_excel(data)
print(data)
# Out:
#     Corriente(A)  Periodo(s)
# 0            1.0       31.76
# 1            1.1       30.97
# 2            1.2       29.32
# 3            1.3       28.63
# 4            1.4       27.43
# 5            1.5       26.36
# 6            1.6       25.49
# 7            1.7       24.95
# 8            1.8       24.47
# 9            1.9       23.55
# 10           2.0       22.95

# %%
x=np.array(data['Corriente(A)'])
y=np.array(data['Periodo(s)'])
ye=np.ones(len(x))*0.01
xe=np.ones(len(x))*0.05

# %%
ye
# Out:
# array([0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05])

# %%
fig, axs = plt.subplots()

axs.errorbar(x, y, xerr=xe,yerr=ye, fmt='o', label='Datos')
axs.plot(x_ac2, slope_ac2 * np.array(x_ac2) + intercept_ac2, label=f'Fit: y={slope_ac2:.2f}x + {intercept_ac2:.2f}')
axs.set_title('Corriente vs Periodo')
axs.set_xlabel('Corriente (A)')
axs.set_ylabel('Periodo (s)')
axs.legend()
axs.grid(True)
