# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy.optimize import curve_fit

data = "C:/Programación/Lab Intermedio/Torque Magnético/AC1.xlsx"
data = pd.read_excel(data)
print(data)
# Out:
#    Distancia(cm)  Corriente (A)
# 0            3.0            2.9
# 1            5.6            3.4
# 2            2.5            2.6
# 3            1.8            2.5
# 4            1.2            2.3
# 5            0.4            2.1
# 6            3.7            3.0

# %%
x=np.array(data['Distancia(cm)'])
y=np.array(data['Corriente (A)'])
ye=np.ones(len(x))*0.05
xe=np.ones(len(x))*0.05

# %%
ye
# Out:
# array([0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05])

# %%
fig, axs = plt.subplots()

axs.errorbar(x, y, xerr=xe,yerr=ye, fmt='o', label='Datos')
axs.plot(x_ac1, slope_ac1 * np.array(x_ac1) + intercept_ac1, label=f'Fit: y={slope_ac1:.2f}x + {intercept_ac1:.2f}')
axs.set_title('Distancia vs Corriente')
axs.set_xlabel('Distancia (cm)')
axs.set_ylabel('Corriente (A)')
axs.legend()
axs.grid(True)

# %%
r=x+1.2+2.15
rmg=r*(1.5/1000)*9.8

# %%
N=195
B=y*(N/)
