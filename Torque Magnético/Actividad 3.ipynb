# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy.optimize import curve_fit

data = "C:/Programación/Lab Intermedio/Torque Magnético/AC3.xlsx"
data = pd.read_excel(data)
print(data)
# Out:
#    Corriente (A)  Periodo (S)
# 0            1.5         5.75
# 1            2.0         4.93
# 2            2.5         4.07
# 3            3.0         3.19
# 4            3.5         3.15
# 5            4.0         2.54

# %%
x=np.array(data['Corriente (A)'])
y=np.array(data['Periodo (S)'])
ye=np.ones(len(x))*0.01
xe=np.ones(len(x))*0.05

# %%
ye
# Out:
# array([0.01, 0.01, 0.01, 0.01, 0.01, 0.01])

# %%
fig, axs = plt.subplots()

axs.errorbar(x, y, xerr=xe,yerr=ye, fmt='o', label='Datos')
axs.plot(x_ac3, slope_ac3 * np.array(x_ac3) + intercept_ac3, label=f'Fit: y={slope_ac3:.2f}x + {intercept_ac3:.2f}')
axs.set_title('Corriente vs Periodo')
axs.set_xlabel('Corriente (A)')
axs.set_ylabel('Periodo (s)')
axs.legend()
axs.grid(True)
