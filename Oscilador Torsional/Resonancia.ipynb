# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy.optimize import curve_fit

data = "C:/Programación/Lab Intermedio/Oscilador Torsional/Resonancia - Oscilador Torsional.xlsx"
data = pd.read_excel(data)
print(data)
# Out:
#     Frecuencia (mHz)  Amplitud (Voltaje)  Frecuencia2 (mHz)  \
# 0                700                0.70                700
# 1                725                0.82                725
# 2                750                0.96                750
# 3                775                1.18                775
# 4                800                1.54                800
# 5                825                2.38                825
# 6                850                4.60                850
# 7                875                4.32                875
# 8                900                2.28                900
# 9                925                1.52                925
# 10               950                1.12                950
# 11               975                0.88                975
# 12              1000                0.76               1000
#
#     Amplitud2 (Voltaje)  Frecuencia3 (mHz)  Amplitud3 (Voltaje)  \
# ...

# %%
x,y=np.array(data['Frecuencia (mHz)']), np.array(data['Amplitud (Voltaje)'])

# %%
fig, ax = plt.subplots()
ax.scatter(x, y)
ax.set_xlabel('T(s)')
ax.set_ylabel('Amplitud (V)')
ax.set_title('Gráfica Resonancia 1 - T(s) vs. Amplitud (V)')
# Out:
# Text(0.5, 1.0, 'Gráfica Resonancia 1 - T(s) vs. Amplitud (V)')

# %%
x1,y1=np.array(data['Frecuencia2 (mHz)']), np.array(data['Amplitud2 (Voltaje)'])

# %%
fig1, ax1 = plt.subplots()
ax1.scatter(x1, y1)
ax1.set_xlabel('T(s)')
ax1.set_ylabel('Amplitud (V)')
ax1.set_title('Gráfica Resonancia 2 - T(s) vs. Amplitud (V)')
# Out:
# Text(0.5, 1.0, 'Gráfica Resonancia 2 - T(s) vs. Amplitud (V)')

# %%
x2,y2=np.array(data['Frecuencia3 (mHz)']), np.array(data['Amplitud3 (Voltaje)'])

# %%
fig2, ax2 = plt.subplots()
ax2.scatter(x2, y2)
ax2.set_xlabel('T(s)')
ax2.set_ylabel('Amplitud (V)')
ax2.set_title('Gráfica Resonancia 3 - T(s) vs. Amplitud (V)')
# Out:
# Text(0.5, 1.0, 'Gráfica Resonancia 3 - T(s) vs. Amplitud (V)')
