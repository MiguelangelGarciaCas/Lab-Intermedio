# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy.optimize import curve_fit

data = "C:/Programación/Lab Intermedio/Oscilador Torsional/Amortiguamiento - Oscilador Torsional.xlsx"
data = pd.read_excel(data)
print(data)
# Out:
#       T_sub1(s)  Amplitud_sub1(V)  T_sub2(s)  Amplitud_sub2(V)  T_sub3(s)  \
# 0         0.000              1.58      0.000             1.560      0.000
# 1         0.004              1.58      0.002             1.560      0.002
# 2         0.008              1.60      0.004             1.560      0.004
# 3         0.012              1.60      0.006             1.552      0.006
# 4         0.016              1.58      0.008             1.560      0.008
# ...         ...               ...        ...               ...        ...
# 2495      9.980             -0.98      4.990             0.800      4.990
# 2496      9.984             -0.98      4.992             0.800      4.992
# 2497      9.988             -0.98      4.994             0.800      4.994
# 2498      9.992             -0.98      4.996             0.800      4.996
# 2499      9.996             -0.98      4.998             0.800      4.998
#
#       Amplitud_sub3(V)  T_critico(s)  Amplitud_critico(V)  T_sobre(s)  \
# ...

# %%
x,y=np.array(data['T_sub1(s)']), np.array(data['Amplitud_sub1(V)'])

# %%
plt.plot(x, y)

# %%
x1=x[481:2179]
y1=y[481:2179]

# %%
fig, ax1 = plt.subplots()
ax1.plot(x1, y1)
ax1.set_xlabel('T(s)')
ax1.set_ylabel('Amplitud (V)')
ax1.set_title('Gráfica Subamortiguamiento 1 - T(s) vs. Amplitud (V)')
# Out:
# Text(0.5, 1.0, 'Gráfica Subamortiguamiento 1 - T(s) vs. Amplitud (V)')

# %%
x2,y2=np.array(data['T_sub2(s)']), np.array(data['Amplitud_sub2(V)'])

# %%
plt.plot(x2, y2)

# %%
x22=x2[573-7:2080-7]
y22=y2[573-7:2080-7]

# %%
fig2, ax2 = plt.subplots()
ax2.plot(x22, y22)
ax2.set_xlabel('T(s)')
ax2.set_ylabel('Amplitud (V)')
ax2.set_title('Gráfica Subamortiguamiento 2 - T(s) vs. Amplitud (V)')
# Out:
# Text(0.5, 1.0, 'Gráfica Subamortiguamiento 2 - T(s) vs. Amplitud (V)')

# %%
x3,y3=np.array(data['T_sub3(s)']), np.array(data['Amplitud_sub3(V)'])

# %%
plt.plot(x3, y3)

# %%
x33=x3[692-7:2455-7]
y33=y3[692-7:2455-7]

# %%
fig3, ax3 = plt.subplots()
ax3.plot(x33, y33)
ax3.set_xlabel('T(s)')
ax3.set_ylabel('Amplitud (V)')
ax3.set_title('Gráfica Subamortiguamiento 3 - T(s) vs. Amplitud (V)')
# Out:
# Text(0.5, 1.0, 'Gráfica Subamortiguamiento 3 - T(s) vs. Amplitud (V)')

# %%
x4,y4=np.array(data['T_critico(s)']), np.array(data['Amplitud_critico(V)'])

# %%
plt.plot(x4, y4)

# %%
x44=x4[896-7:1568-7]
y44=y4[896-7:1568-7]

# %%
fig4, ax4 = plt.subplots()
ax4.plot(x44, y44)
ax4.set_xlabel('T(s)')
ax4.set_ylabel('Amplitud (V)')
ax4.set_title('Gráfica Amortiguamiento Crítico - T(s) vs. Amplitud (V)')
# Out:
# Text(0.5, 1.0, 'Gráfica Amortiguamiento Crítico - T(s) vs. Amplitud (V)')

# %%
x5,y5=np.array(data['T_sobre(s)']), np.array(data['Amplitud_sobre(V)'])

# %%
plt.plot(x5,y5)

# %%
x55=x5[896-7:1568-7]
y55=y5[896-7:1568-7]

# %%
fig5, ax5 = plt.subplots()
ax5.plot(x55, y55)
ax5.set_xlabel('T(s)')
ax5.set_ylabel('Amplitud (V)')
ax5.set_title('Gráfica Sobreamortiguamiento - T(s) vs. Amplitud (V)')
# Out:
# Text(0.5, 1.0, 'Gráfica Sobreamortiguamiento - T(s) vs. Amplitud (V)')
