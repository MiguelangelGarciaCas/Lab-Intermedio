# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy.optimize import curve_fit

data = "C:/Programación/Lab Intermedio/Rayos X/Vacio.xlsx"
data = pd.read_excel(data)
data
# Out:
#     Ángulo del cristal  Tasa con 30kV
# 0                    6            488
# 1                    7            390
# 2                    8            270
# 3                    9            181
# 4                   10            145
# 5                   11            144
# 6                   12            145
# 7                   13            146
# 8                   14            145
# 9                   15            143
# 10                  16            175

# %%
x,y = np.array(data['Ángulo del cristal']), np.array(data['Tasa con 30kV'])

# %%
fig, ax = plt.subplots()
ax.plot(x, y, color='r', label='Tasa con 30kV')

#plt.legend(['Regresión Lineal: Intercepto '])
ax.legend(loc='upper right')
ax.set_xlabel('Intensidad (Imp/s))')
ax.set_ylabel('Ángulo de la ruedad (°)')
ax.set_title('Intensidad (Imp/s) vs.Ángulo de la ruedad (°)')
# Out:
# Text(0.5, 1.0, 'Intensidad (Imp/s) vs.Ángulo de la ruedad (°)')

# %%
plt.plot(x,y)
